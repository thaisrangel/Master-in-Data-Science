# %% [markdown]
# ejercicio 1: contar lineas

# %%
import pandas as pd
import numpy as np

# %%
from pandas import Series,DataFrame

# %%
# sin comprimir
f = open('bookings.csv.bz2', 'r')
n = 0
for l in f:
    n += 1
print(n)
# Out:
# 1825298

# %%
# comrimido
ls = f.readlines()
len(ls)
# Out:
# 0

# %%
import bz2

# %%
f = bz2.BZ2File('bookings.csv.bz2')

# %%
f

# %%
n = 0
for l in f:
    n += 1

# %%
n
# Out:
# 10000011

# %% [markdown]
# # ejercicio 2: top 10 arrival airports in the world in 2013

# %%
import pandas as pd

# %%
b = pd.read_csv('bookings.csv.bz2', sep='^', nrows=1e5)

# %%
b.head()
# Out:
#    act_date             source  pos_ctry                          pos_iata  \
# 0  2013-03-05 00:00:00  1A      DE        a68dd7ae953c8acfb187a1af2dcbe123
# 1  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 2  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 3  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
# 4  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
#
#                           pos_oid                      rloc            \
# 0  1a11ae49fcbf545fd2afc1a24d88d2b7  ea65900e72d71f4626378e2ebd298267
# 1  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 2  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 3  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
# 4  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
#
#    cre_date             duration  distance  dep_port    ...      \
# 0  2013-02-22 00:00:00      1708         0  ZRH         ...
# 1  2013-03-26 00:00:00    135270         0  SAL         ...
# 2  2013-03-26 00:00:00    135270         0  SAL         ...
# 3  2013-03-26 00:00:00     30885         0  AKL         ...
# 4  2013-03-26 00:00:00     30885         0  AKL         ...
#
#    route           carrier  bkg_class  cab_class  brd_time             \
# 0  LHRZRH               VI  T          Y          2013-03-07 08:50:00
# 1  SALATLCLT            NV  L          Y          2013-04-12 13:04:00
# 2  CLTATLSAL            NV  U          Y          2013-07-15 07:00:00
# 3  AKLHKGSVO            XK  G          Y          2013-04-24 23:59:00
# 4  SVOHKGAKL            XK  G          Y          2013-05-14 20:15:00
#
#    off_time            pax  year month  oid
# 0  2013-03-07 11:33:37  -1  2013     3  NULL
# 1  2013-04-12 22:05:40   1  2013     3  NULL
# 2  2013-07-15 11:34:51   1  2013     3  NULL
# 3  2013-04-25 16:06:31   1  2013     3  SYDA82546
# 4  2013-05-16 10:44:50   1  2013     3  SYDA82546
#
# [5 rows x 38 columns]

# %%
b.columns
# Out:
# Index([u'act_date           ', u'source', u'pos_ctry', u'pos_iata',
#        u'pos_oid  ', u'rloc          ', u'cre_date           ', u'duration',
#        u'distance', u'dep_port', u'dep_city', u'dep_ctry', u'arr_port',
#        u'arr_city', u'arr_ctry', u'lst_port', u'lst_city', u'lst_ctry',
#        u'brd_port', u'brd_city', u'brd_ctry', u'off_port', u'off_city',
#        u'off_ctry', u'mkt_port', u'mkt_city', u'mkt_ctry', u'intl',
#        u'route          ', u'carrier', u'bkg_class', u'cab_class',
#        u'brd_time           ', u'off_time           ', u'pax', u'year',
#        u'month', u'oid      '],
#       dtype='object')

# %%
df = b[['arr_port', 'pax']].groupby("arr_port").sum().sort("pax", ascending=False).head(10)

# %%
df
# Out:
#            pax
# arr_port
# LHR       1006
# MCO        861
# JFK        795
# LAX        761
# BKK        747
# LAS        732
# SFO        705
# ORD        686
# CDG        676
# DXB        587

# %%
df.reset_index()
# Out:
#    arr_port   pax
# 0  LHR       1006
# 1  MCO        861
# 2  JFK        795
# 3  LAX        761
# 4  BKK        747
# 5  LAS        732
# 6  SFO        705
# 7  ORD        686
# 8  CDG        676
# 9  DXB        587

# %% [markdown]
# 2nda solucion del ejercicio 2

# %%
g = b.groupby('arr_port')

# %%
s = g.pax.sum()

# %%
d = s.reset_index()

# %%
d.head(3)
# Out:
#    arr_port  pax
# 0  AAE         2
# 1  AAL        16
# 2  AAQ         5

# %%
d.sort('pax', ascending=False).head(10)
# Out:
#       arr_port   pax
# 733   LHR       1006
# 798   MCO        861
# 620   JFK        795
# 706   LAX        761
# 156   BKK        747
# 704   LAS        732
# 1159  SFO        705
# 957   ORD        686
# 232   CDG        676
# 366   DXB        587

# %% [markdown]
# ejercicio 2 - class code (done using chunks)

# %%
import pandas as pd

# %%
b = pd.read_csv('bookings.csv.bz2', sep='^', chunksize=1e5)

# %%
b

# %%
for chunk in b:
    print(chunk.__class__)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# /usr/lib64/python2.7/site-packages/pandas/io/parsers.py:1170: DtypeWarning: Columns (7,8,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
lista=[]
for chunk in b:
    lista.append(chunk[['arr_port','pax']].groupby("arr_port").sum().sort("pax",ascending=False))

# %%
lista
# Out:
# [           pax
#  arr_port
#  LHR       1006
#  MCO        861
#  JFK        795
#  LAX        761
#  BKK        747
#  LAS        732
#  SFO        705
#  ORD        686
#  CDG        676
#  DXB        587
#  MIA        585
#  EWR        539
#  DFW        514
#  ATL        498
#  IST        497
#  FCO        479
#  LGA        472
#  CUN        447
#  FLL        435
#  DEN        403
#  HKG        400
#  BOS        387
#  DCA        381
#  PHX        377
#  PEK        375
#  SEA        363
#  BOM        361
#  MAD        356
#  HNL        352
#  MUC        344
#  ...        ...
#  EZS         -2
#  URY         -2
#  IXL         -2
#  XUZ         -2
#  YAY         -2
#  HDS         -2
#  MAO         -3
#  IGU         -3
#  HMB         -3
#  ASU         -3
#  JHB         -3
#  ASR         -4
#  XMB         -4
#  RFP         -4
#  LDH         -4
#  FSC         -5
#  BOB         -5
#  STS         -6
#  KSN         -6
#  LGK         -6
#  KLU         -6
#  RAR         -8
#  PRI         -8
#  BEL         -8
#  MOZ        -14
#  RIX        -21
#  LXR        -30
#  DBV        -30
#  KZN        -45
#  AYQ       -146
#
#  [1506 rows x 1 columns],           pax
#  arr_port
#  LHR       968
#  MCO       870
#  LAS       781
#  MIA       706
#  CDG       700
#  LAX       697
#  CUN       677
#  SFO       616
#  JFK       603
#  BCN       584
#  DXB       560
#  BKK       533
#  ORD       495
#  IST       473
#  DFW       454
#  ATL       406
#  FCO       404
#  MAD       389
#  TXL       374
#  DEN       363
#  PHX       357
#  MNL       354
#  SEA       350
#  FRA       350
#  BOM       344
#  MUC       343
#  DEL       334
#  JNB       331
#  MEL       325
#  DCA       325
#  ...       ...
#  ZLO        -2
#  CRK        -2
#  ZDH        -2
#  BOB        -2
#  BTU        -2
#  KUA        -2
#  CFE        -2
#  TGG        -2
#  ISN        -2
#  LUG        -2
#  JIB        -2
#  TAC        -2
#  LBF        -2
#  KVA        -3
#  AXU        -3
#  MCZ        -3
#  RAB        -4
#  REP        -4
#  VLI        -4
#  LPB        -4
#  PRI        -4
#  CWB        -5
#  FUK        -5
#  ESU        -6
#  NAV        -6
#  XNN        -6
#  SKP        -7
#  VXE        -8
#  FCA       -10
#  KGD       -59
#
#  [1496 rows x 1 columns],            pax
#  arr_port
#  LHR       1024
#  MCO        785
#  LAX        774
#  LAS        739
#  CDG        705
#  JFK        693
#  BKK        648
#  DXB        631
#  SFO        590
#  MIA        586
#  ORD        514
#  MAD        493
#  DFW        491
#  IST        477
#  FCO        464
#  ATL        422
#  BCN        396
#  BOS        390
#  EWR        386
#  PHX        381
#  MNL        379
#  CUN        377
#  ORY        357
#  LGA        354
#  HKG        352
#  TXL        344
#  SYD        342
#  AMS        334
#  DEN        332
#  BOM        332
#  ...        ...
#  TMM         -1
#  PUQ         -1
#  PTG         -1
#  AGT         -1
#  TUG         -2
#  HMA         -2
#  MRA         -2
#  RMQ         -2
#  KYA         -2
#  KPO         -2
#  UDI         -2
#  MSU         -2
#  VDM         -2
#  FNA         -2
#  ASM         -2
#  DOM         -2
#  LTN         -2
#  TAG         -2
#  LEI         -2
#  CGD         -3
#  OBO         -6
#  EBL         -7
#  SAH         -9
#  DRW        -10
#  AJR        -12
#  FTE        -12
#  AAL        -19
#  ACE        -42
#  SXF       -112
#  LCA       -116
#
#  [1478 rows x 1 columns],           pax
#  arr_port
#  LHR       952
#  MIA       791
#  LAX       737
#  CDG       714
#  JFK       713
#  MCO       697
#  SFO       636
#  BKK       611
#  LAS       602
#  ORD       546
#  FCO       545
#  DXB       506
#  IST       499
#  ATL       485
#  BCN       475
#  MAD       468
#  DFW       434
#  CUN       431
#  LGA       420
#  BOS       404
#  EWR       402
#  HKG       380
#  FRA       380
#  JED       373
#  SYD       365
#  MNL       355
#  ORY       355
#  FLL       351
#  YYZ       343
#  BOM       331
#  ...       ...
#  FCA        -3
#  SUB        -3
#  SDJ        -4
#  TMS        -4
#  INN        -4
#  RSU        -4
#  IXA        -4
#  JER        -4
#  YFC        -4
#  SPU        -4
#  ZNZ        -4
#  LFW        -5
#  YQL        -5
#  DIE        -5
#  MRA        -5
#  FAE        -6
#  MCZ        -6
#  ASM        -6
#  HAK        -6
#  BTU        -7
#  SID        -7
#  NSN        -7
#  SLU        -8
#  NOS        -8
#  HDN       -10
#  ASR       -10
#  CTS       -10
#  AZS       -11
#  LLA       -11
#  SCQ       -98
#
#  [1534 rows x 1 columns],           pax
#  arr_port
#  LHR       729
#  MCO       686
#  JFK       686
#  LAX       673
#  CDG       637
#  BCN       594
#  LAS       550
#  DXB       549
#  MIA       539
#  SFO       495
#  BKK       482
#  IST       480
#  CUN       479
#  FCO       473
#  MAD       437
#  ORD       425
#  DFW       403
#  ATL       379
#  LGA       372
#  EWR       364
#  DEL       360
#  MNL       347
#  BOS       341
#  BOM       326
#  SIN       324
#  ORY       322
#  YYZ       321
#  SYD       320
#  DEN       313
#  ATH       311
#  ...       ...
#  HDG        -2
#  RCB        -2
#  UIB        -2
#  JPA        -2
#  BTS        -3
#  JRO        -3
#  MWZ        -3
#  IKT        -3
#  ISU        -3
#  ABT        -4
#  SNE        -4
#  UAQ        -4
#  GDZ        -4
#  GAY        -4
#  KKE        -4
#  KWL        -4
#  NDR        -4
#  NVT        -5
#  ALF        -5
#  SMX        -5
#  SLU        -6
#  LUG        -6
#  STM        -6
#  LPB        -6
#  CRK        -7
#  ZCO        -8
#  MYJ        -8
#  RRG       -11
#  URC       -12
#  SPU       -24
#
#  [1543 rows x 1 columns],           pax
#  arr_port
#  LHR       792
#  LAS       711
#  MCO       646
#  LAX       602
#  JFK       601
#  BKK       594
#  SFO       577
#  DXB       570
#  FCO       547
#  CDG       537
#  ORD       514
#  DEL       448
#  LGA       407
#  AMS       404
#  MAD       400
#  IST       395
#  MIA       388
#  EWR       373
#  DFW       363
#  SYD       359
#  BOS       357
#  FRA       335
#  PEK       334
#  MUC       333
#  HKG       324
#  TXL       318
#  CUN       316
#  ATL       315
#  DCA       313
#  IAH       308
#  ...       ...
#  NQY        -2
#  BAV        -2
#  VIG        -2
#  LAU        -2
#  POZ        -3
#  RRG        -3
#  BJV        -3
#  SWA        -3
#  KMG        -3
#  HAH        -4
#  VFA        -4
#  KYA        -4
#  LAO        -4
#  JRH        -4
#  KLO        -4
#  ROT        -4
#  ROB        -5
#  MLN        -6
#  HOR        -6
#  GND        -8
#  SEZ        -8
#  USH        -8
#  UPG        -8
#  KVG       -10
#  BKI       -14
#  SPN       -14
#  JOG       -18
#  CXR       -20
#  OPO       -30
#  KRN       -40
#
#  [1558 rows x 1 columns],           pax
#  arr_port
#  LHR       942
#  LAX       833
#  JFK       701
#  CDG       685
#  MCO       670
#  LAS       652
#  MIA       617
#  ORD       573
#  BKK       497
#  DXB       479
#  SFO       471
#  FCO       421
#  SYD       421
#  LGA       419
#  BOS       413
#  TXL       404
#  DFW       404
#  TLV       402
#  MAD       398
#  SEA       378
#  IST       377
#  PVG       377
#  ATL       369
#  FRA       353
#  DEL       349
#  BCN       345
#  BOM       335
#  AMS       330
#  MNL       329
#  CUN       318
#  ...       ...
#  YKM        -2
#  KGF        -2
#  BGM        -2
#  TZX        -2
#  HAH        -2
#  GTR        -2
#  ZYL        -3
#  LSC        -3
#  FLN        -3
#  SHA        -3
#  ASW        -3
#  LYP        -3
#  AGA        -3
#  BBA        -3
#  BPN        -3
#  LLW        -3
#  REP        -4
#  XWG        -4
#  GWT        -4
#  PRI        -4
#  ROB        -5
#  MUA        -6
#  CSX        -6
#  DJE        -6
#  BOB       -10
#  WNZ       -16
#  LXR       -18
#  TRN       -40
#  OLB       -42
#  GUM       -48
#
#  [1559 rows x 1 columns],           pax
#  arr_port
#  LHR       869
#  LAX       777
#  LAS       681
#  CDG       610
#  SFO       591
#  DXB       589
#  BKK       558
#  MCO       525
#  JFK       504
#  MUC       477
#  ORD       460
#  MAD       451
#  MIA       445
#  EWR       430
#  IST       425
#  FCO       414
#  AMS       405
#  DEL       400
#  SYD       399
#  LGA       398
#  VIE       384
#  BOM       371
#  ATL       371
#  DFW       369
#  FLL       366
#  CUN       362
#  BCN       350
#  BOS       334
#  FRA       333
#  JED       323
#  ...       ...
#  LFW        -2
#  EUN        -2
#  CAY        -2
#  XNB        -2
#  XOP        -2
#  SHW        -2
#  NKC        -3
#  CJU        -3
#  KZO        -3
#  XJY        -3
#  FOR        -3
#  KKJ        -4
#  AOJ        -4
#  NLK        -4
#  FLA        -4
#  APW        -4
#  SDK        -4
#  OXB        -4
#  UPG        -4
#  ABS        -5
#  MSO        -5
#  LEJ        -5
#  ULN        -6
#  RGI       -10
#  FCA       -11
#  FTE       -12
#  RFP       -14
#  RRG       -22
#  SJO       -33
#  OSD       -38
#
#  [1575 rows x 1 columns],           pax
#  arr_port
#  LHR       872
#  JFK       850
#  LAS       725
#  MCO       683
#  MIA       632
#  BKK       631
#  ORD       614
#  CDG       596
#  SFO       527
#  DXB       516
#  LAX       496
#  IST       455
#  CUN       409
#  MAD       397
#  DFW       388
#  LGA       368
#  BCN       353
#  ORY       350
#  MEX       349
#  MNL       348
#  DEL       344
#  MUC       341
#  EWR       340
#  LIS       332
#  ATL       326
#  HKG       326
#  AMS       320
#  GVA       318
#  BOM       317
#  BOS       309
#  ...       ...
#  EJA        -4
#  SLU        -4
#  KUU        -4
#  RMQ        -4
#  PRI        -4
#  EKO        -4
#  INH        -4
#  LOP        -4
#  SIT        -4
#  XWG        -4
#  PEM        -4
#  DYU        -4
#  PPN        -5
#  ASR        -5
#  WDH        -5
#  NCL        -6
#  ROR        -6
#  HOR        -6
#  QSF        -6
#  LCA        -6
#  LFW        -6
#  OXB        -6
#  JOG        -7
#  DME        -7
#  IXB        -7
#  ZNZ       -10
#  ALC       -13
#  FLW       -19
#  HRK       -19
#  MZV       -35
#
#  [1529 rows x 1 columns],           pax
#  arr_port
#  LAS       790
#  LHR       727
#  LAX       703
#  MCO       670
#  BKK       645
#  SFO       592
#  CDG       589
#  DXB       572
#  LGA       544
#  MIA       526
#  ORD       493
#  JFK       481
#  FCO       461
#  BCN       427
#  DFW       422
#  DEL       417
#  ATL       407
#  HKG       401
#  CUN       384
#  ATH       363
#  DEN       359
#  MAD       352
#  SYD       340
#  BOS       340
#  BOM       333
#  ORY       332
#  SEA       321
#  TXL       315
#  MUC       310
#  IST       307
#  ...       ...
#  SFL        -2
#  GOP        -2
#  MGF        -2
#  ULN        -3
#  RAB        -3
#  CCP        -3
#  IXZ        -3
#  SHW        -3
#  MOZ        -4
#  MVY        -4
#  YXY        -4
#  MIR        -4
#  LAU        -4
#  MPH        -4
#  CSG        -4
#  BPS        -5
#  BOB        -6
#  ERZ        -6
#  LRM        -6
#  LTN        -6
#  ZYL        -7
#  SDJ        -7
#  ITO        -7
#  JRO        -9
#  SXR        -9
#  INN       -10
#  LAP       -12
#  MHH       -12
#  SPN       -13
#  SPC      -108
#
#  [1553 rows x 1 columns],            pax
#  arr_port
#  LHR       1006
#  MCO        861
#  JFK        795
#  LAX        761
#  BKK        747
#  LAS        732
#  SFO        705
#  ORD        686
#  CDG        676
#  DXB        587
#  MIA        585
#  EWR        539
#  DFW        514
#  ATL        498
#  IST        497
#  FCO        479
#  LGA        472
#  CUN        447
#  FLL        435
#  DEN        403
#  HKG        400
#  BOS        387
#  DCA        381
#  PHX        377
#  PEK        375
#  SEA        363
#  BOM        361
#  MAD        356
#  HNL        352
#  MUC        344
#  ...        ...
#  EZS         -2
#  URY         -2
#  IXL         -2
#  XUZ         -2
#  YAY         -2
#  HDS         -2
#  MAO         -3
#  IGU         -3
#  HMB         -3
#  ASU         -3
#  JHB         -3
#  ASR         -4
#  XMB         -4
#  RFP         -4
#  LDH         -4
#  FSC         -5
#  BOB         -5
#  STS         -6
#  KSN         -6
#  LGK         -6
#  KLU         -6
#  RAR         -8
#  PRI         -8
#  BEL         -8
#  MOZ        -14
#  RIX        -21
#  LXR        -30
#  DBV        -30
#  KZN        -45
#  AYQ       -146
#
#  [1506 rows x 1 columns],           pax
#  arr_port
#  LHR       968
#  MCO       870
#  LAS       781
#  MIA       706
#  CDG       700
#  LAX       697
#  CUN       677
#  SFO       616
#  JFK       603
#  BCN       584
#  DXB       560
#  BKK       533
#  ORD       495
#  IST       473
#  DFW       454
#  ATL       406
#  FCO       404
#  MAD       389
#  TXL       374
#  DEN       363
#  PHX       357
#  MNL       354
#  SEA       350
#  FRA       350
#  BOM       344
#  MUC       343
#  DEL       334
#  JNB       331
#  MEL       325
#  DCA       325
#  ...       ...
#  ZLO        -2
#  CRK        -2
#  ZDH        -2
#  BOB        -2
#  BTU        -2
#  KUA        -2
#  CFE        -2
#  TGG        -2
#  ISN        -2
#  LUG        -2
#  JIB        -2
#  TAC        -2
#  LBF        -2
#  KVA        -3
#  AXU        -3
#  MCZ        -3
#  RAB        -4
#  REP        -4
#  VLI        -4
#  LPB        -4
#  PRI        -4
#  CWB        -5
#  FUK        -5
#  ESU        -6
#  NAV        -6
#  XNN        -6
#  SKP        -7
#  VXE        -8
#  FCA       -10
#  KGD       -59
#
#  [1496 rows x 1 columns],            pax
#  arr_port
#  LHR       1024
#  MCO        785
#  LAX        774
#  LAS        739
#  CDG        705
#  JFK        693
#  BKK        648
#  DXB        631
#  SFO        590
#  MIA        586
#  ORD        514
#  MAD        493
#  DFW        491
#  IST        477
#  FCO        464
#  ATL        422
#  BCN        396
#  BOS        390
#  EWR        386
#  PHX        381
#  MNL        379
#  CUN        377
#  ORY        357
#  LGA        354
#  HKG        352
#  TXL        344
#  SYD        342
#  AMS        334
#  DEN        332
#  BOM        332
#  ...        ...
#  TMM         -1
#  PUQ         -1
#  PTG         -1
#  AGT         -1
#  TUG         -2
#  HMA         -2
#  MRA         -2
#  RMQ         -2
#  KYA         -2
#  KPO         -2
#  UDI         -2
#  MSU         -2
#  VDM         -2
#  FNA         -2
#  ASM         -2
#  DOM         -2
#  LTN         -2
#  TAG         -2
#  LEI         -2
#  CGD         -3
#  OBO         -6
#  EBL         -7
#  SAH         -9
#  DRW        -10
#  AJR        -12
#  FTE        -12
#  AAL        -19
#  ACE        -42
#  SXF       -112
#  LCA       -116
#
#  [1478 rows x 1 columns],           pax
#  arr_port
#  LHR       952
#  MIA       791
#  LAX       737
#  CDG       714
#  JFK       713
#  MCO       697
#  SFO       636
#  BKK       611
#  LAS       602
#  ORD       546
#  FCO       545
#  DXB       506
#  IST       499
#  ATL       485
#  BCN       475
#  MAD       468
#  DFW       434
#  CUN       431
#  LGA       420
#  BOS       404
#  EWR       402
#  HKG       380
#  FRA       380
#  JED       373
#  SYD       365
#  MNL       355
#  ORY       355
#  FLL       351
#  YYZ       343
#  BOM       331
#  ...       ...
#  FCA        -3
#  SUB        -3
#  SDJ        -4
#  TMS        -4
#  INN        -4
#  RSU        -4
#  IXA        -4
#  JER        -4
#  YFC        -4
#  SPU        -4
#  ZNZ        -4
#  LFW        -5
#  YQL        -5
#  DIE        -5
#  MRA        -5
#  FAE        -6
#  MCZ        -6
#  ASM        -6
#  HAK        -6
#  BTU        -7
#  SID        -7
#  NSN        -7
#  SLU        -8
#  NOS        -8
#  HDN       -10
#  ASR       -10
#  CTS       -10
#  AZS       -11
#  LLA       -11
#  SCQ       -98
#
#  [1534 rows x 1 columns],           pax
#  arr_port
#  LHR       729
#  MCO       686
#  JFK       686
#  LAX       673
#  CDG       637
#  BCN       594
#  LAS       550
#  DXB       549
#  MIA       539
#  SFO       495
#  BKK       482
#  IST       480
#  CUN       479
#  FCO       473
#  MAD       437
#  ORD       425
#  DFW       403
#  ATL       379
#  LGA       372
#  EWR       364
#  DEL       360
#  MNL       347
#  BOS       341
#  BOM       326
#  SIN       324
#  ORY       322
#  YYZ       321
#  SYD       320
#  DEN       313
#  ATH       311
#  ...       ...
#  HDG        -2
#  RCB        -2
#  UIB        -2
#  JPA        -2
#  BTS        -3
#  JRO        -3
#  MWZ        -3
#  IKT        -3
#  ISU        -3
#  ABT        -4
#  SNE        -4
#  UAQ        -4
#  GDZ        -4
#  GAY        -4
#  KKE        -4
#  KWL        -4
#  NDR        -4
#  NVT        -5
#  ALF        -5
#  SMX        -5
#  SLU        -6
#  LUG        -6
#  STM        -6
#  LPB        -6
#  CRK        -7
#  ZCO        -8
#  MYJ        -8
#  RRG       -11
#  URC       -12
#  SPU       -24
#
#  [1543 rows x 1 columns],           pax
#  arr_port
#  LHR       792
#  LAS       711
#  MCO       646
#  LAX       602
#  JFK       601
#  BKK       594
#  SFO       577
#  DXB       570
#  FCO       547
#  CDG       537
#  ORD       514
#  DEL       448
#  LGA       407
#  AMS       404
#  MAD       400
#  IST       395
#  MIA       388
#  EWR       373
#  DFW       363
#  SYD       359
#  BOS       357
#  FRA       335
#  PEK       334
#  MUC       333
#  HKG       324
#  TXL       318
#  CUN       316
#  ATL       315
#  DCA       313
#  IAH       308
#  ...       ...
#  NQY        -2
#  BAV        -2
#  VIG        -2
#  LAU        -2
#  POZ        -3
#  RRG        -3
#  BJV        -3
#  SWA        -3
#  KMG        -3
#  HAH        -4
#  VFA        -4
#  KYA        -4
#  LAO        -4
#  JRH        -4
#  KLO        -4
#  ROT        -4
#  ROB        -5
#  MLN        -6
#  HOR        -6
#  GND        -8
#  SEZ        -8
#  USH        -8
#  UPG        -8
#  KVG       -10
#  BKI       -14
#  SPN       -14
#  JOG       -18
#  CXR       -20
#  OPO       -30
#  KRN       -40
#
#  [1558 rows x 1 columns],           pax
#  arr_port
#  LHR       942
#  LAX       833
#  JFK       701
#  CDG       685
#  MCO       670
#  LAS       652
#  MIA       617
#  ORD       573
#  BKK       497
#  DXB       479
#  SFO       471
#  FCO       421
#  SYD       421
#  LGA       419
#  BOS       413
#  TXL       404
#  DFW       404
#  TLV       402
#  MAD       398
#  SEA       378
#  IST       377
#  PVG       377
#  ATL       369
#  FRA       353
#  DEL       349
#  BCN       345
#  BOM       335
#  AMS       330
#  MNL       329
#  CUN       318
#  ...       ...
#  YKM        -2
#  KGF        -2
#  BGM        -2
#  TZX        -2
#  HAH        -2
#  GTR        -2
#  ZYL        -3
#  LSC        -3
#  FLN        -3
#  SHA        -3
#  ASW        -3
#  LYP        -3
#  AGA        -3
#  BBA        -3
#  BPN        -3
#  LLW        -3
#  REP        -4
#  XWG        -4
#  GWT        -4
#  PRI        -4
#  ROB        -5
#  MUA        -6
#  CSX        -6
#  DJE        -6
#  BOB       -10
#  WNZ       -16
#  LXR       -18
#  TRN       -40
#  OLB       -42
#  GUM       -48
#
#  [1559 rows x 1 columns],           pax
#  arr_port
#  LHR       869
#  LAX       777
#  LAS       681
#  CDG       610
#  SFO       591
#  DXB       589
#  BKK       558
#  MCO       525
#  JFK       504
#  MUC       477
#  ORD       460
#  MAD       451
#  MIA       445
#  EWR       430
#  IST       425
#  FCO       414
#  AMS       405
#  DEL       400
#  SYD       399
#  LGA       398
#  VIE       384
#  BOM       371
#  ATL       371
#  DFW       369
#  FLL       366
#  CUN       362
#  BCN       350
#  BOS       334
#  FRA       333
#  JED       323
#  ...       ...
#  LFW        -2
#  EUN        -2
#  CAY        -2
#  XNB        -2
#  XOP        -2
#  SHW        -2
#  NKC        -3
#  CJU        -3
#  KZO        -3
#  XJY        -3
#  FOR        -3
#  KKJ        -4
#  AOJ        -4
#  NLK        -4
#  FLA        -4
#  APW        -4
#  SDK        -4
#  OXB        -4
#  UPG        -4
#  ABS        -5
#  MSO        -5
#  LEJ        -5
#  ULN        -6
#  RGI       -10
#  FCA       -11
#  FTE       -12
#  RFP       -14
#  RRG       -22
#  SJO       -33
#  OSD       -38
#
#  [1575 rows x 1 columns],           pax
#  arr_port
#  LHR       872
#  JFK       850
#  LAS       725
#  MCO       683
#  MIA       632
#  BKK       631
#  ORD       614
#  CDG       596
#  SFO       527
#  DXB       516
#  LAX       496
#  IST       455
#  CUN       409
#  MAD       397
#  DFW       388
#  LGA       368
#  BCN       353
#  ORY       350
#  MEX       349
#  MNL       348
#  DEL       344
#  MUC       341
#  EWR       340
#  LIS       332
#  ATL       326
#  HKG       326
#  AMS       320
#  GVA       318
#  BOM       317
#  BOS       309
#  ...       ...
#  EJA        -4
#  SLU        -4
#  KUU        -4
#  RMQ        -4
#  PRI        -4
#  EKO        -4
#  INH        -4
#  LOP        -4
#  SIT        -4
#  XWG        -4
#  PEM        -4
#  DYU        -4
#  PPN        -5
#  ASR        -5
#  WDH        -5
#  NCL        -6
#  ROR        -6
#  HOR        -6
#  QSF        -6
#  LCA        -6
#  LFW        -6
#  OXB        -6
#  JOG        -7
#  DME        -7
#  IXB        -7
#  ZNZ       -10
#  ALC       -13
#  FLW       -19
#  HRK       -19
#  MZV       -35
#
#  [1529 rows x 1 columns],           pax
#  arr_port
#  LAS       790
#  LHR       727
#  LAX       703
#  MCO       670
#  BKK       645
#  SFO       592
#  CDG       589
#  DXB       572
#  LGA       544
#  MIA       526
#  ORD       493
#  JFK       481
#  FCO       461
#  BCN       427
#  DFW       422
#  DEL       417
#  ATL       407
#  HKG       401
#  CUN       384
#  ATH       363
#  DEN       359
#  MAD       352
#  SYD       340
#  BOS       340
#  BOM       333
#  ORY       332
#  SEA       321
#  TXL       315
#  MUC       310
#  IST       307
#  ...       ...
#  SFL        -2
#  GOP        -2
#  MGF        -2
#  ULN        -3
#  RAB        -3
#  CCP        -3
#  IXZ        -3
#  SHW        -3
#  MOZ        -4
#  MVY        -4
#  YXY        -4
#  MIR        -4
#  LAU        -4
#  MPH        -4
#  CSG        -4
#  BPS        -5
#  BOB        -6
#  ERZ        -6
#  LRM        -6
#  LTN        -6
#  ZYL        -7
#  SDJ        -7
#  ITO        -7
#  JRO        -9
#  SXR        -9
#  INN       -10
#  LAP       -12
#  MHH       -12
#  SPN       -13
#  SPC      -108
#
#  [1553 rows x 1 columns],            pax
#  arr_port
#  LHR       1006
#  MCO        861
#  JFK        795
#  LAX        761
#  BKK        747
#  LAS        732
#  SFO        705
#  ORD        686
#  CDG        676
#  DXB        587
#  MIA        585
#  EWR        539
#  DFW        514
#  ATL        498
#  IST        497
#  FCO        479
#  LGA        472
#  CUN        447
#  FLL        435
#  DEN        403
#  HKG        400
#  BOS        387
#  DCA        381
#  PHX        377
#  PEK        375
#  SEA        363
#  BOM        361
#  MAD        356
#  HNL        352
#  MUC        344
#  ...        ...
#  EZS         -2
#  URY         -2
#  IXL         -2
#  XUZ         -2
#  YAY         -2
#  HDS         -2
#  MAO         -3
#  IGU         -3
#  HMB         -3
#  ASU         -3
#  JHB         -3
#  ASR         -4
#  XMB         -4
#  RFP         -4
#  LDH         -4
#  FSC         -5
#  BOB         -5
#  STS         -6
#  KSN         -6
#  LGK         -6
#  KLU         -6
#  RAR         -8
#  PRI         -8
#  BEL         -8
#  MOZ        -14
#  RIX        -21
#  LXR        -30
#  DBV        -30
#  KZN        -45
#  AYQ       -146
#
#  [1506 rows x 1 columns],           pax
#  arr_port
#  LHR       968
#  MCO       870
#  LAS       781
#  MIA       706
#  CDG       700
#  LAX       697
#  CUN       677
#  SFO       616
#  JFK       603
#  BCN       584
#  DXB       560
#  BKK       533
#  ORD       495
#  IST       473
#  DFW       454
#  ATL       406
#  FCO       404
#  MAD       389
#  TXL       374
#  DEN       363
#  PHX       357
#  MNL       354
#  SEA       350
#  FRA       350
#  BOM       344
#  MUC       343
#  DEL       334
#  JNB       331
#  MEL       325
#  DCA       325
#  ...       ...
#  ZLO        -2
#  CRK        -2
#  ZDH        -2
#  BOB        -2
#  BTU        -2
#  KUA        -2
#  CFE        -2
#  TGG        -2
#  ISN        -2
#  LUG        -2
#  JIB        -2
#  TAC        -2
#  LBF        -2
#  KVA        -3
#  AXU        -3
#  MCZ        -3
#  RAB        -4
#  REP        -4
#  VLI        -4
#  LPB        -4
#  PRI        -4
#  CWB        -5
#  FUK        -5
#  ESU        -6
#  NAV        -6
#  XNN        -6
#  SKP        -7
#  VXE        -8
#  FCA       -10
#  KGD       -59
#
#  [1496 rows x 1 columns],            pax
#  arr_port
#  LHR       1024
#  MCO        785
#  LAX        774
#  LAS        739
#  CDG        705
#  JFK        693
#  BKK        648
#  DXB        631
#  SFO        590
#  MIA        586
#  ORD        514
#  MAD        493
#  DFW        491
#  IST        477
#  FCO        464
#  ATL        422
#  BCN        396
#  BOS        390
#  EWR        386
#  PHX        381
#  MNL        379
#  CUN        377
#  ORY        357
#  LGA        354
#  HKG        352
#  TXL        344
#  SYD        342
#  AMS        334
#  DEN        332
#  BOM        332
#  ...        ...
#  TMM         -1
#  PUQ         -1
#  PTG         -1
#  AGT         -1
#  TUG         -2
#  HMA         -2
#  MRA         -2
#  RMQ         -2
#  KYA         -2
#  KPO         -2
#  UDI         -2
#  MSU         -2
#  VDM         -2
#  FNA         -2
#  ASM         -2
#  DOM         -2
#  LTN         -2
#  TAG         -2
#  LEI         -2
#  CGD         -3
#  OBO         -6
#  EBL         -7
#  SAH         -9
#  DRW        -10
#  AJR        -12
#  FTE        -12
#  AAL        -19
#  ACE        -42
#  SXF       -112
#  LCA       -116
#
#  [1478 rows x 1 columns],           pax
#  arr_port
#  LHR       952
#  MIA       791
#  LAX       737
#  CDG       714
#  JFK       713
#  MCO       697
#  SFO       636
#  BKK       611
#  LAS       602
#  ORD       546
#  FCO       545
#  DXB       506
#  IST       499
#  ATL       485
#  BCN       475
#  MAD       468
#  DFW       434
#  CUN       431
#  LGA       420
#  BOS       404
#  EWR       402
#  HKG       380
#  FRA       380
#  JED       373
#  SYD       365
#  MNL       355
#  ORY       355
#  FLL       351
#  YYZ       343
#  BOM       331
#  ...       ...
#  FCA        -3
#  SUB        -3
#  SDJ        -4
#  TMS        -4
#  INN        -4
#  RSU        -4
#  IXA        -4
#  JER        -4
#  YFC        -4
#  SPU        -4
#  ZNZ        -4
#  LFW        -5
#  YQL        -5
#  DIE        -5
#  MRA        -5
#  FAE        -6
#  MCZ        -6
#  ASM        -6
#  HAK        -6
#  BTU        -7
#  SID        -7
#  NSN        -7
#  SLU        -8
#  NOS        -8
#  HDN       -10
#  ASR       -10
#  CTS       -10
#  AZS       -11
#  LLA       -11
#  SCQ       -98
#
#  [1534 rows x 1 columns],           pax
#  arr_port
#  LHR       729
#  MCO       686
#  JFK       686
#  LAX       673
#  CDG       637
#  BCN       594
#  LAS       550
#  DXB       549
#  MIA       539
#  SFO       495
#  BKK       482
#  IST       480
#  CUN       479
#  FCO       473
#  MAD       437
#  ORD       425
#  DFW       403
#  ATL       379
#  LGA       372
#  EWR       364
#  DEL       360
#  MNL       347
#  BOS       341
#  BOM       326
#  SIN       324
#  ORY       322
#  YYZ       321
#  SYD       320
#  DEN       313
#  ATH       311
#  ...       ...
#  HDG        -2
#  RCB        -2
#  UIB        -2
#  JPA        -2
#  BTS        -3
#  JRO        -3
#  MWZ        -3
#  IKT        -3
#  ISU        -3
#  ABT        -4
#  SNE        -4
#  UAQ        -4
#  GDZ        -4
#  GAY        -4
#  KKE        -4
#  KWL        -4
#  NDR        -4
#  NVT        -5
#  ALF        -5
#  SMX        -5
#  SLU        -6
#  LUG        -6
#  STM        -6
#  LPB        -6
#  CRK        -7
#  ZCO        -8
#  MYJ        -8
#  RRG       -11
#  URC       -12
#  SPU       -24
#
#  [1543 rows x 1 columns],           pax
#  arr_port
#  LHR       792
#  LAS       711
#  MCO       646
#  LAX       602
#  JFK       601
#  BKK       594
#  SFO       577
#  DXB       570
#  FCO       547
#  CDG       537
#  ORD       514
#  DEL       448
#  LGA       407
#  AMS       404
#  MAD       400
#  IST       395
#  MIA       388
#  EWR       373
#  DFW       363
#  SYD       359
#  BOS       357
#  FRA       335
#  PEK       334
#  MUC       333
#  HKG       324
#  TXL       318
#  CUN       316
#  ATL       315
#  DCA       313
#  IAH       308
#  ...       ...
#  NQY        -2
#  BAV        -2
#  VIG        -2
#  LAU        -2
#  POZ        -3
#  RRG        -3
#  BJV        -3
#  SWA        -3
#  KMG        -3
#  HAH        -4
#  VFA        -4
#  KYA        -4
#  LAO        -4
#  JRH        -4
#  KLO        -4
#  ROT        -4
#  ROB        -5
#  MLN        -6
#  HOR        -6
#  GND        -8
#  SEZ        -8
#  USH        -8
#  UPG        -8
#  KVG       -10
#  BKI       -14
#  SPN       -14
#  JOG       -18
#  CXR       -20
#  OPO       -30
#  KRN       -40
#
#  [1558 rows x 1 columns],           pax
#  arr_port
#  LHR       942
#  LAX       833
#  JFK       701
#  CDG       685
#  MCO       670
#  LAS       652
#  MIA       617
#  ORD       573
#  BKK       497
#  DXB       479
#  SFO       471
#  FCO       421
#  SYD       421
#  LGA       419
#  BOS       413
#  TXL       404
#  DFW       404
#  TLV       402
#  MAD       398
#  SEA       378
#  IST       377
#  PVG       377
#  ATL       369
#  FRA       353
#  DEL       349
#  BCN       345
#  BOM       335
#  AMS       330
#  MNL       329
#  CUN       318
#  ...       ...
#  YKM        -2
#  KGF        -2
#  BGM        -2
#  TZX        -2
#  HAH        -2
#  GTR        -2
#  ZYL        -3
#  LSC        -3
#  FLN        -3
#  SHA        -3
#  ASW        -3
#  LYP        -3
#  AGA        -3
#  BBA        -3
#  BPN        -3
#  LLW        -3
#  REP        -4
#  XWG        -4
#  GWT        -4
#  PRI        -4
#  ROB        -5
#  MUA        -6
#  CSX        -6
#  DJE        -6
#  BOB       -10
#  WNZ       -16
#  LXR       -18
#  TRN       -40
#  OLB       -42
#  GUM       -48
#
#  [1559 rows x 1 columns],           pax
#  arr_port
#  LHR       869
#  LAX       777
#  LAS       681
#  CDG       610
#  SFO       591
#  DXB       589
#  BKK       558
#  MCO       525
#  JFK       504
#  MUC       477
#  ORD       460
#  MAD       451
#  MIA       445
#  EWR       430
#  IST       425
#  FCO       414
#  AMS       405
#  DEL       400
#  SYD       399
#  LGA       398
#  VIE       384
#  BOM       371
#  ATL       371
#  DFW       369
#  FLL       366
#  CUN       362
#  BCN       350
#  BOS       334
#  FRA       333
#  JED       323
#  ...       ...
#  LFW        -2
#  EUN        -2
#  CAY        -2
#  XNB        -2
#  XOP        -2
#  SHW        -2
#  NKC        -3
#  CJU        -3
#  KZO        -3
#  XJY        -3
#  FOR        -3
#  KKJ        -4
#  AOJ        -4
#  NLK        -4
#  FLA        -4
#  APW        -4
#  SDK        -4
#  OXB        -4
#  UPG        -4
#  ABS        -5
#  MSO        -5
#  LEJ        -5
#  ULN        -6
#  RGI       -10
#  FCA       -11
#  FTE       -12
#  RFP       -14
#  RRG       -22
#  SJO       -33
#  OSD       -38
#
#  [1575 rows x 1 columns],           pax
#  arr_port
#  LHR       872
#  JFK       850
#  LAS       725
#  MCO       683
#  MIA       632
#  BKK       631
#  ORD       614
#  CDG       596
#  SFO       527
#  DXB       516
#  LAX       496
#  IST       455
#  CUN       409
#  MAD       397
#  DFW       388
#  LGA       368
#  BCN       353
#  ORY       350
#  MEX       349
#  MNL       348
#  DEL       344
#  MUC       341
#  EWR       340
#  LIS       332
#  ATL       326
#  HKG       326
#  AMS       320
#  GVA       318
#  BOM       317
#  BOS       309
#  ...       ...
#  EJA        -4
#  SLU        -4
#  KUU        -4
#  RMQ        -4
#  PRI        -4
#  EKO        -4
#  INH        -4
#  LOP        -4
#  SIT        -4
#  XWG        -4
#  PEM        -4
#  DYU        -4
#  PPN        -5
#  ASR        -5
#  WDH        -5
#  NCL        -6
#  ROR        -6
#  HOR        -6
#  QSF        -6
#  LCA        -6
#  LFW        -6
#  OXB        -6
#  JOG        -7
#  DME        -7
#  IXB        -7
#  ZNZ       -10
#  ALC       -13
#  FLW       -19
#  HRK       -19
#  MZV       -35
#
#  [1529 rows x 1 columns],           pax
#  arr_port
#  LAS       790
#  LHR       727
#  LAX       703
#  MCO       670
#  BKK       645
#  SFO       592
#  CDG       589
#  DXB       572
#  LGA       544
#  MIA       526
#  ORD       493
#  JFK       481
#  FCO       461
#  BCN       427
#  DFW       422
#  DEL       417
#  ATL       407
#  HKG       401
#  CUN       384
#  ATH       363
#  DEN       359
#  MAD       352
#  SYD       340
#  BOS       340
#  BOM       333
#  ORY       332
#  SEA       321
#  TXL       315
#  MUC       310
#  IST       307
#  ...       ...
#  SFL        -2
#  GOP        -2
#  MGF        -2
#  ULN        -3
#  RAB        -3
#  CCP        -3
#  IXZ        -3
#  SHW        -3
#  MOZ        -4
#  MVY        -4
#  YXY        -4
#  MIR        -4
#  LAU        -4
#  MPH        -4
#  CSG        -4
#  BPS        -5
#  BOB        -6
#  ERZ        -6
#  LRM        -6
#  LTN        -6
#  ZYL        -7
#  SDJ        -7
#  ITO        -7
#  JRO        -9
#  SXR        -9
#  INN       -10
#  LAP       -12
#  MHH       -12
#  SPN       -13
#  SPC      -108
#
#  [1553 rows x 1 columns],            pax
#  arr_port
#  LHR       1006
#  MCO        861
#  JFK        795
#  LAX        761
#  BKK        747
#  LAS        732
#  SFO        705
#  ORD        686
#  CDG        676
#  DXB        587
#  MIA        585
#  EWR        539
#  DFW        514
#  ATL        498
#  IST        497
#  FCO        479
#  LGA        472
#  CUN        447
#  FLL        435
#  DEN        403
#  HKG        400
#  BOS        387
#  DCA        381
#  PHX        377
#  PEK        375
#  SEA        363
#  BOM        361
#  MAD        356
#  HNL        352
#  MUC        344
#  ...        ...
#  EZS         -2
#  URY         -2
#  IXL         -2
#  XUZ         -2
#  YAY         -2
#  HDS         -2
#  MAO         -3
#  IGU         -3
#  HMB         -3
#  ASU         -3
#  JHB         -3
#  ASR         -4
#  XMB         -4
#  RFP         -4
#  LDH         -4
#  FSC         -5
#  BOB         -5
#  STS         -6
#  KSN         -6
#  LGK         -6
#  KLU         -6
#  RAR         -8
#  PRI         -8
#  BEL         -8
#  MOZ        -14
#  RIX        -21
#  LXR        -30
#  DBV        -30
#  KZN        -45
#  AYQ       -146
#
#  [1506 rows x 1 columns],           pax
#  arr_port
#  LHR       968
#  MCO       870
#  LAS       781
#  MIA       706
#  CDG       700
#  LAX       697
#  CUN       677
#  SFO       616
#  JFK       603
#  BCN       584
#  DXB       560
#  BKK       533
#  ORD       495
#  IST       473
#  DFW       454
#  ATL       406
#  FCO       404
#  MAD       389
#  TXL       374
#  DEN       363
#  PHX       357
#  MNL       354
#  SEA       350
#  FRA       350
#  BOM       344
#  MUC       343
#  DEL       334
#  JNB       331
#  MEL       325
#  DCA       325
#  ...       ...
#  ZLO        -2
#  CRK        -2
#  ZDH        -2
#  BOB        -2
#  BTU        -2
#  KUA        -2
#  CFE        -2
#  TGG        -2
#  ISN        -2
#  LUG        -2
#  JIB        -2
#  TAC        -2
#  LBF        -2
#  KVA        -3
#  AXU        -3
#  MCZ        -3
#  RAB        -4
#  REP        -4
#  VLI        -4
#  LPB        -4
#  PRI        -4
#  CWB        -5
#  FUK        -5
#  ESU        -6
#  NAV        -6
#  XNN        -6
#  SKP        -7
#  VXE        -8
#  FCA       -10
#  KGD       -59
#
#  [1496 rows x 1 columns],            pax
#  arr_port
#  LHR       1024
#  MCO        785
#  LAX        774
#  LAS        739
#  CDG        705
#  JFK        693
#  BKK        648
#  DXB        631
#  SFO        590
#  MIA        586
#  ORD        514
#  MAD        493
#  DFW        491
#  IST        477
#  FCO        464
#  ATL        422
#  BCN        396
#  BOS        390
#  EWR        386
#  PHX        381
#  MNL        379
#  CUN        377
#  ORY        357
#  LGA        354
#  HKG        352
#  TXL        344
#  SYD        342
#  AMS        334
#  DEN        332
#  BOM        332
#  ...        ...
#  TMM         -1
#  PUQ         -1
#  PTG         -1
#  AGT         -1
#  TUG         -2
#  HMA         -2
#  MRA         -2
#  RMQ         -2
#  KYA         -2
#  KPO         -2
#  UDI         -2
#  MSU         -2
#  VDM         -2
#  FNA         -2
#  ASM         -2
#  DOM         -2
#  LTN         -2
#  TAG         -2
#  LEI         -2
#  CGD         -3
#  OBO         -6
#  EBL         -7
#  SAH         -9
#  DRW        -10
#  AJR        -12
#  FTE        -12
#  AAL        -19
#  ACE        -42
#  SXF       -112
#  LCA       -116
#
#  [1478 rows x 1 columns],           pax
#  arr_port
#  LHR       952
#  MIA       791
#  LAX       737
#  CDG       714
#  JFK       713
#  MCO       697
#  SFO       636
#  BKK       611
#  LAS       602
#  ORD       546
#  FCO       545
#  DXB       506
#  IST       499
#  ATL       485
#  BCN       475
#  MAD       468
#  DFW       434
#  CUN       431
#  LGA       420
#  BOS       404
#  EWR       402
#  HKG       380
#  FRA       380
#  JED       373
#  SYD       365
#  MNL       355
#  ORY       355
#  FLL       351
#  YYZ       343
#  BOM       331
#  ...       ...
#  FCA        -3
#  SUB        -3
#  SDJ        -4
#  TMS        -4
#  INN        -4
#  RSU        -4
#  IXA        -4
#  JER        -4
#  YFC        -4
#  SPU        -4
#  ZNZ        -4
#  LFW        -5
#  YQL        -5
#  DIE        -5
#  MRA        -5
#  FAE        -6
#  MCZ        -6
#  ASM        -6
#  HAK        -6
#  BTU        -7
#  SID        -7
#  NSN        -7
#  SLU        -8
#  NOS        -8
#  HDN       -10
#  ASR       -10
#  CTS       -10
#  AZS       -11
#  LLA       -11
#  SCQ       -98
#
#  [1534 rows x 1 columns],           pax
#  arr_port
#  LHR       729
#  MCO       686
#  JFK       686
#  LAX       673
#  CDG       637
#  BCN       594
#  LAS       550
#  DXB       549
#  MIA       539
#  SFO       495
#  BKK       482
#  IST       480
#  CUN       479
#  FCO       473
#  MAD       437
#  ORD       425
#  DFW       403
#  ATL       379
#  LGA       372
#  EWR       364
#  DEL       360
#  MNL       347
#  BOS       341
#  BOM       326
#  SIN       324
#  ORY       322
#  YYZ       321
#  SYD       320
#  DEN       313
#  ATH       311
#  ...       ...
#  HDG        -2
#  RCB        -2
#  UIB        -2
#  JPA        -2
#  BTS        -3
#  JRO        -3
#  MWZ        -3
#  IKT        -3
#  ISU        -3
#  ABT        -4
#  SNE        -4
#  UAQ        -4
#  GDZ        -4
#  GAY        -4
#  KKE        -4
#  KWL        -4
#  NDR        -4
#  NVT        -5
#  ALF        -5
#  SMX        -5
#  SLU        -6
#  LUG        -6
#  STM        -6
#  LPB        -6
#  CRK        -7
#  ZCO        -8
#  MYJ        -8
#  RRG       -11
#  URC       -12
#  SPU       -24
#
#  [1543 rows x 1 columns],           pax
#  arr_port
#  LHR       792
#  LAS       711
#  MCO       646
#  LAX       602
#  JFK       601
#  BKK       594
#  SFO       577
#  DXB       570
#  FCO       547
#  CDG       537
#  ORD       514
#  DEL       448
#  LGA       407
#  AMS       404
#  MAD       400
#  IST       395
#  MIA       388
#  EWR       373
#  DFW       363
#  SYD       359
#  BOS       357
#  FRA       335
#  PEK       334
#  MUC       333
#  HKG       324
#  TXL       318
#  CUN       316
#  ATL       315
#  DCA       313
#  IAH       308
#  ...       ...
#  NQY        -2
#  BAV        -2
#  VIG        -2
#  LAU        -2
#  POZ        -3
#  RRG        -3
#  BJV        -3
#  SWA        -3
#  KMG        -3
#  HAH        -4
#  VFA        -4
#  KYA        -4
#  LAO        -4
#  JRH        -4
#  KLO        -4
#  ROT        -4
#  ROB        -5
#  MLN        -6
#  HOR        -6
#  GND        -8
#  SEZ        -8
#  USH        -8
#  UPG        -8
#  KVG       -10
#  BKI       -14
#  SPN       -14
#  JOG       -18
#  CXR       -20
#  OPO       -30
#  KRN       -40
#
#  [1558 rows x 1 columns],           pax
#  arr_port
#  LHR       942
#  LAX       833
#  JFK       701
#  CDG       685
#  MCO       670
#  LAS       652
#  MIA       617
#  ORD       573
#  BKK       497
#  DXB       479
#  SFO       471
#  FCO       421
#  SYD       421
#  LGA       419
#  BOS       413
#  TXL       404
#  DFW       404
#  TLV       402
#  MAD       398
#  SEA       378
#  IST       377
#  PVG       377
#  ATL       369
#  FRA       353
#  DEL       349
#  BCN       345
#  BOM       335
#  AMS       330
#  MNL       329
#  CUN       318
#  ...       ...
#  YKM        -2
#  KGF        -2
#  BGM        -2
#  TZX        -2
#  HAH        -2
#  GTR        -2
#  ZYL        -3
#  LSC        -3
#  FLN        -3
#  SHA        -3
#  ASW        -3
#  LYP        -3
#  AGA        -3
#  BBA        -3
#  BPN        -3
#  LLW        -3
#  REP        -4
#  XWG        -4
#  GWT        -4
#  PRI        -4
#  ROB        -5
#  MUA        -6
#  CSX        -6
#  DJE        -6
#  BOB       -10
#  WNZ       -16
#  LXR       -18
#  TRN       -40
#  OLB       -42
#  GUM       -48
#
#  [1559 rows x 1 columns],           pax
#  arr_port
#  LHR       869
#  LAX       777
#  LAS       681
#  CDG       610
#  SFO       591
#  DXB       589
#  BKK       558
#  MCO       525
#  JFK       504
#  MUC       477
#  ORD       460
#  MAD       451
#  MIA       445
#  EWR       430
#  IST       425
#  FCO       414
#  AMS       405
#  DEL       400
#  SYD       399
#  LGA       398
#  VIE       384
#  BOM       371
#  ATL       371
#  DFW       369
#  FLL       366
#  CUN       362
#  BCN       350
#  BOS       334
#  FRA       333
#  JED       323
#  ...       ...
#  LFW        -2
#  EUN        -2
#  CAY        -2
#  XNB        -2
#  XOP        -2
#  SHW        -2
#  NKC        -3
#  CJU        -3
#  KZO        -3
#  XJY        -3
#  FOR        -3
#  KKJ        -4
#  AOJ        -4
#  NLK        -4
#  FLA        -4
#  APW        -4
#  SDK        -4
#  OXB        -4
#  UPG        -4
#  ABS        -5
#  MSO        -5
#  LEJ        -5
#  ULN        -6
#  RGI       -10
#  FCA       -11
#  FTE       -12
#  RFP       -14
#  RRG       -22
#  SJO       -33
#  OSD       -38
#
#  [1575 rows x 1 columns],           pax
#  arr_port
#  LHR       872
#  JFK       850
#  LAS       725
#  MCO       683
#  MIA       632
#  BKK       631
#  ORD       614
#  CDG       596
#  SFO       527
#  DXB       516
#  LAX       496
#  IST       455
#  CUN       409
#  MAD       397
#  DFW       388
#  LGA       368
#  BCN       353
#  ORY       350
#  MEX       349
#  MNL       348
#  DEL       344
#  MUC       341
#  EWR       340
#  LIS       332
#  ATL       326
#  HKG       326
#  AMS       320
#  GVA       318
#  BOM       317
#  BOS       309
#  ...       ...
#  EJA        -4
#  SLU        -4
#  KUU        -4
#  RMQ        -4
#  PRI        -4
#  EKO        -4
#  INH        -4
#  LOP        -4
#  SIT        -4
#  XWG        -4
#  PEM        -4
#  DYU        -4
#  PPN        -5
#  ASR        -5
#  WDH        -5
#  NCL        -6
#  ROR        -6
#  HOR        -6
#  QSF        -6
#  LCA        -6
#  LFW        -6
#  OXB        -6
#  JOG        -7
#  DME        -7
#  IXB        -7
#  ZNZ       -10
#  ALC       -13
#  FLW       -19
#  HRK       -19
#  MZV       -35
#
#  [1529 rows x 1 columns],           pax
#  arr_port
#  LAS       790
#  LHR       727
#  LAX       703
#  MCO       670
#  BKK       645
#  SFO       592
#  CDG       589
#  DXB       572
#  LGA       544
#  MIA       526
#  ORD       493
#  JFK       481
#  FCO       461
#  BCN       427
#  DFW       422
#  DEL       417
#  ATL       407
#  HKG       401
#  CUN       384
#  ATH       363
#  DEN       359
#  MAD       352
#  SYD       340
#  BOS       340
#  BOM       333
#  ORY       332
#  SEA       321
#  TXL       315
#  MUC       310
#  IST       307
#  ...       ...
#  SFL        -2
#  GOP        -2
#  MGF        -2
#  ULN        -3
#  RAB        -3
#  CCP        -3
#  IXZ        -3
#  SHW        -3
#  MOZ        -4
#  MVY        -4
#  YXY        -4
#  MIR        -4
#  LAU        -4
#  MPH        -4
#  CSG        -4
#  BPS        -5
#  BOB        -6
#  ERZ        -6
#  LRM        -6
#  LTN        -6
#  ZYL        -7
#  SDJ        -7
#  ITO        -7
#  JRO        -9
#  SXR        -9
#  INN       -10
#  LAP       -12
#  MHH       -12
#  SPN       -13
#  SPC      -108
#
#  [1553 rows x 1 columns],            pax
#  arr_port
#  LHR       1006
#  MCO        861
#  JFK        795
#  LAX        761
#  BKK        747
#  LAS        732
#  SFO        705
#  ORD        686
#  CDG        676
#  DXB        587
#  MIA        585
#  EWR        539
#  DFW        514
#  ATL        498
#  IST        497
#  FCO        479
#  LGA        472
#  CUN        447
#  FLL        435
#  DEN        403
#  HKG        400
#  BOS        387
#  DCA        381
#  PHX        377
#  PEK        375
#  SEA        363
#  BOM        361
#  MAD        356
#  HNL        352
#  MUC        344
#  ...        ...
#  EZS         -2
#  URY         -2
#  IXL         -2
#  XUZ         -2
#  YAY         -2
#  HDS         -2
#  MAO         -3
#  IGU         -3
#  HMB         -3
#  ASU         -3
#  JHB         -3
#  ASR         -4
#  XMB         -4
#  RFP         -4
#  LDH         -4
#  FSC         -5
#  BOB         -5
#  STS         -6
#  KSN         -6
#  LGK         -6
#  KLU         -6
#  RAR         -8
#  PRI         -8
#  BEL         -8
#  MOZ        -14
#  RIX        -21
#  LXR        -30
#  DBV        -30
#  KZN        -45
#  AYQ       -146
#
#  [1506 rows x 1 columns],           pax
#  arr_port
#  LHR       968
#  MCO       870
#  LAS       781
#  MIA       706
#  CDG       700
#  LAX       697
#  CUN       677
#  SFO       616
#  JFK       603
#  BCN       584
#  DXB       560
#  BKK       533
#  ORD       495
#  IST       473
#  DFW       454
#  ATL       406
#  FCO       404
#  MAD       389
#  TXL       374
#  DEN       363
#  PHX       357
#  MNL       354
#  SEA       350
#  FRA       350
#  BOM       344
#  MUC       343
#  DEL       334
#  JNB       331
#  MEL       325
#  DCA       325
#  ...       ...
#  ZLO        -2
#  CRK        -2
#  ZDH        -2
#  BOB        -2
#  BTU        -2
#  KUA        -2
#  CFE        -2
#  TGG        -2
#  ISN        -2
#  LUG        -2
#  JIB        -2
#  TAC        -2
#  LBF        -2
#  KVA        -3
#  AXU        -3
#  MCZ        -3
#  RAB        -4
#  REP        -4
#  VLI        -4
#  LPB        -4
#  PRI        -4
#  CWB        -5
#  FUK        -5
#  ESU        -6
#  NAV        -6
#  XNN        -6
#  SKP        -7
#  VXE        -8
#  FCA       -10
#  KGD       -59
#
#  [1496 rows x 1 columns],            pax
#  arr_port
#  LHR       1024
#  MCO        785
#  LAX        774
#  LAS        739
#  CDG        705
#  JFK        693
#  BKK        648
#  DXB        631
#  SFO        590
#  MIA        586
#  ORD        514
#  MAD        493
#  DFW        491
#  IST        477
#  FCO        464
#  ATL        422
#  BCN        396
#  BOS        390
#  EWR        386
#  PHX        381
#  MNL        379
#  CUN        377
#  ORY        357
#  LGA        354
#  HKG        352
#  TXL        344
#  SYD        342
#  AMS        334
#  DEN        332
#  BOM        332
#  ...        ...
#  TMM         -1
#  PUQ         -1
#  PTG         -1
#  AGT         -1
#  TUG         -2
#  HMA         -2
#  MRA         -2
#  RMQ         -2
#  KYA         -2
#  KPO         -2
#  UDI         -2
#  MSU         -2
#  VDM         -2
#  FNA         -2
#  ASM         -2
#  DOM         -2
#  LTN         -2
#  TAG         -2
#  LEI         -2
#  CGD         -3
#  OBO         -6
#  EBL         -7
#  SAH         -9
#  DRW        -10
#  AJR        -12
#  FTE        -12
#  AAL        -19
#  ACE        -42
#  SXF       -112
#  LCA       -116
#
#  [1478 rows x 1 columns],           pax
#  arr_port
#  LHR       952
#  MIA       791
#  LAX       737
#  CDG       714
#  JFK       713
#  MCO       697
#  SFO       636
#  BKK       611
#  LAS       602
#  ORD       546
#  FCO       545
#  DXB       506
#  IST       499
#  ATL       485
#  BCN       475
#  MAD       468
#  DFW       434
#  CUN       431
#  LGA       420
#  BOS       404
#  EWR       402
#  HKG       380
#  FRA       380
#  JED       373
#  SYD       365
#  MNL       355
#  ORY       355
#  FLL       351
#  YYZ       343
#  BOM       331
#  ...       ...
#  FCA        -3
#  SUB        -3
#  SDJ        -4
#  TMS        -4
#  INN        -4
#  RSU        -4
#  IXA        -4
#  JER        -4
#  YFC        -4
#  SPU        -4
#  ZNZ        -4
#  LFW        -5
#  YQL        -5
#  DIE        -5
#  MRA        -5
#  FAE        -6
#  MCZ        -6
#  ASM        -6
#  HAK        -6
#  BTU        -7
#  SID        -7
#  NSN        -7
#  SLU        -8
#  NOS        -8
#  HDN       -10
#  ASR       -10
#  CTS       -10
#  AZS       -11
#  LLA       -11
#  SCQ       -98
#
#  [1534 rows x 1 columns],           pax
#  arr_port
#  LHR       729
#  MCO       686
#  JFK       686
#  LAX       673
#  CDG       637
#  BCN       594
#  LAS       550
#  DXB       549
#  MIA       539
#  SFO       495
#  BKK       482
#  IST       480
#  CUN       479
#  FCO       473
#  MAD       437
#  ORD       425
#  DFW       403
#  ATL       379
#  LGA       372
#  EWR       364
#  DEL       360
#  MNL       347
#  BOS       341
#  BOM       326
#  SIN       324
#  ORY       322
#  YYZ       321
#  SYD       320
#  DEN       313
#  ATH       311
#  ...       ...
#  HDG        -2
#  RCB        -2
#  UIB        -2
#  JPA        -2
#  BTS        -3
#  JRO        -3
#  MWZ        -3
#  IKT        -3
#  ISU        -3
#  ABT        -4
#  SNE        -4
#  UAQ        -4
#  GDZ        -4
#  GAY        -4
#  KKE        -4
#  KWL        -4
#  NDR        -4
#  NVT        -5
#  ALF        -5
#  SMX        -5
#  SLU        -6
#  LUG        -6
#  STM        -6
#  LPB        -6
#  CRK        -7
#  ZCO        -8
#  MYJ        -8
#  RRG       -11
#  URC       -12
#  SPU       -24
#
#  [1543 rows x 1 columns],           pax
#  arr_port
#  LHR       792
#  LAS       711
#  MCO       646
#  LAX       602
#  JFK       601
#  BKK       594
#  SFO       577
#  DXB       570
#  FCO       547
#  CDG       537
#  ORD       514
#  DEL       448
#  LGA       407
#  AMS       404
#  MAD       400
#  IST       395
#  MIA       388
#  EWR       373
#  DFW       363
#  SYD       359
#  BOS       357
#  FRA       335
#  PEK       334
#  MUC       333
#  HKG       324
#  TXL       318
#  CUN       316
#  ATL       315
#  DCA       313
#  IAH       308
#  ...       ...
#  NQY        -2
#  BAV        -2
#  VIG        -2
#  LAU        -2
#  POZ        -3
#  RRG        -3
#  BJV        -3
#  SWA        -3
#  KMG        -3
#  HAH        -4
#  VFA        -4
#  KYA        -4
#  LAO        -4
#  JRH        -4
#  KLO        -4
#  ROT        -4
#  ROB        -5
#  MLN        -6
#  HOR        -6
#  GND        -8
#  SEZ        -8
#  USH        -8
#  UPG        -8
#  KVG       -10
#  BKI       -14
#  SPN       -14
#  JOG       -18
#  CXR       -20
#  OPO       -30
#  KRN       -40
#
#  [1558 rows x 1 columns],           pax
#  arr_port
#  LHR       942
#  LAX       833
#  JFK       701
#  CDG       685
#  MCO       670
#  LAS       652
#  MIA       617
#  ORD       573
#  BKK       497
#  DXB       479
#  SFO       471
#  FCO       421
#  SYD       421
#  LGA       419
#  BOS       413
#  TXL       404
#  DFW       404
#  TLV       402
#  MAD       398
#  SEA       378
#  IST       377
#  PVG       377
#  ATL       369
#  FRA       353
#  DEL       349
#  BCN       345
#  BOM       335
#  AMS       330
#  MNL       329
#  CUN       318
#  ...       ...
#  YKM        -2
#  KGF        -2
#  BGM        -2
#  TZX        -2
#  HAH        -2
#  GTR        -2
#  ZYL        -3
#  LSC        -3
#  FLN        -3
#  SHA        -3
#  ASW        -3
#  LYP        -3
#  AGA        -3
#  BBA        -3
#  BPN        -3
#  LLW        -3
#  REP        -4
#  XWG        -4
#  GWT        -4
#  PRI        -4
#  ROB        -5
#  MUA        -6
#  CSX        -6
#  DJE        -6
#  BOB       -10
#  WNZ       -16
#  LXR       -18
#  TRN       -40
#  OLB       -42
#  GUM       -48
#
#  [1559 rows x 1 columns],           pax
#  arr_port
#  LHR       869
#  LAX       777
#  LAS       681
#  CDG       610
#  SFO       591
#  DXB       589
#  BKK       558
#  MCO       525
#  JFK       504
#  MUC       477
#  ORD       460
#  MAD       451
#  MIA       445
#  EWR       430
#  IST       425
#  FCO       414
#  AMS       405
#  DEL       400
#  SYD       399
#  LGA       398
#  VIE       384
#  BOM       371
#  ATL       371
#  DFW       369
#  FLL       366
#  CUN       362
#  BCN       350
#  BOS       334
#  FRA       333
#  JED       323
#  ...       ...
#  LFW        -2
#  EUN        -2
#  CAY        -2
#  XNB        -2
#  XOP        -2
#  SHW        -2
#  NKC        -3
#  CJU        -3
#  KZO        -3
#  XJY        -3
#  FOR        -3
#  KKJ        -4
#  AOJ        -4
#  NLK        -4
#  FLA        -4
#  APW        -4
#  SDK        -4
#  OXB        -4
#  UPG        -4
#  ABS        -5
#  MSO        -5
#  LEJ        -5
#  ULN        -6
#  RGI       -10
#  FCA       -11
#  FTE       -12
#  RFP       -14
#  RRG       -22
#  SJO       -33
#  OSD       -38
#
#  [1575 rows x 1 columns],           pax
#  arr_port
#  LHR       872
#  JFK       850
#  LAS       725
#  MCO       683
#  MIA       632
#  BKK       631
#  ORD       614
#  CDG       596
#  SFO       527
#  DXB       516
#  LAX       496
#  IST       455
#  CUN       409
#  MAD       397
#  DFW       388
#  LGA       368
#  BCN       353
#  ORY       350
#  MEX       349
#  MNL       348
#  DEL       344
#  MUC       341
#  EWR       340
#  LIS       332
#  ATL       326
#  HKG       326
#  AMS       320
#  GVA       318
#  BOM       317
#  BOS       309
#  ...       ...
#  EJA        -4
#  SLU        -4
#  KUU        -4
#  RMQ        -4
#  PRI        -4
#  EKO        -4
#  INH        -4
#  LOP        -4
#  SIT        -4
#  XWG        -4
#  PEM        -4
#  DYU        -4
#  PPN        -5
#  ASR        -5
# ...
#  HAK        -6
#  BTU        -7
#  SID        -7
#  NSN        -7
#  SLU        -8
#  NOS        -8
#  HDN       -10
#  ASR       -10
#  CTS       -10
#  AZS       -11
#  LLA       -11
#  SCQ       -98
#
#  [1534 rows x 1 columns],           pax
#  arr_port
#  LHR       729
#  MCO       686
#  JFK       684
#  LAX       673
#  CDG       637
#  BCN       594
#  LAS       550
#  DXB       549
#  MIA       539
#  SFO       495
#  IST       480
#  BKK       480
#  CUN       479
#  FCO       473
#  MAD       437
#  ORD       425
#  DFW       403
#  ATL       379
#  LGA       374
#  EWR       366
#  DEL       360
#  MNL       347
#  BOS       341
#  BOM       326
#  SIN       324
#  ORY       322
#  YYZ       321
#  SYD       320
#  DEN       313
#  ATH       311
#  ...       ...
#  HDG        -2
#  RCB        -2
#  UIB        -2
#  JPA        -2
#  BTS        -3
#  JRO        -3
#  MWZ        -3
#  IKT        -3
#  ISU        -3
#  ABT        -4
#  SNE        -4
#  UAQ        -4
#  GDZ        -4
#  GAY        -4
#  KKE        -4
#  KWL        -4
#  NDR        -4
#  NVT        -5
#  ALF        -5
#  SMX        -5
#  SLU        -6
#  LUG        -6
#  STM        -6
#  LPB        -6
#  CRK        -7
#  ZCO        -8
#  MYJ        -8
#  RRG       -11
#  URC       -12
#  SPU       -24
#
#  [1543 rows x 1 columns],           pax
#  arr_port
#  LHR       792
#  LAS       711
#  MCO       646
#  JFK       603
#  LAX       602
#  BKK       596
#  SFO       577
#  DXB       570
#  FCO       547
#  CDG       537
#  ORD       514
#  DEL       448
#  LGA       407
#  AMS       404
#  MAD       400
#  IST       395
#  MIA       388
#  EWR       373
#  DFW       363
#  SYD       359
#  BOS       357
#  FRA       335
#  PEK       334
#  MUC       333
#  HKG       324
#  TXL       320
#  CUN       316
#  ATL       315
#  DCA       313
#  IAH       308
#  ...       ...
#  JST        -2
#  ZOS        -2
#  APL        -2
#  OSM        -2
#  SWA        -3
#  BJV        -3
#  RRG        -3
#  KMG        -3
#  POZ        -3
#  ROT        -4
#  LAO        -4
#  KYA        -4
#  KLO        -4
#  VFA        -4
#  HAH        -4
#  JRH        -4
#  ROB        -5
#  MLN        -6
#  HOR        -6
#  GND        -8
#  SEZ        -8
#  USH        -8
#  UPG        -8
#  KVG       -10
#  SPN       -14
#  BKI       -14
#  JOG       -18
#  CXR       -20
#  OPO       -30
#  KRN       -40
#
#  [1559 rows x 1 columns],           pax
#  arr_port
#  LHR       942
#  LAX       835
#  JFK       701
#  CDG       685
#  MCO       670
#  LAS       652
#  MIA       617
#  ORD       573
#  BKK       495
#  DXB       479
#  SFO       471
#  FCO       421
#  SYD       421
#  LGA       419
#  BOS       413
#  TXL       404
#  DFW       404
#  TLV       402
#  MAD       398
#  SEA       378
#  PVG       378
#  IST       377
#  ATL       369
#  FRA       353
#  DEL       349
#  BCN       345
#  BOM       335
#  AMS       330
#  MNL       329
#  CUN       318
#  ...       ...
#  YKM        -2
#  KGF        -2
#  BGM        -2
#  TZX        -2
#  HAH        -2
#  GTR        -2
#  ZYL        -3
#  LSC        -3
#  FLN        -3
#  SHA        -3
#  ASW        -3
#  LYP        -3
#  AGA        -3
#  BBA        -3
#  BPN        -3
#  LLW        -3
#  REP        -4
#  XWG        -4
#  GWT        -4
#  PRI        -4
#  ROB        -5
#  MUA        -6
#  CSX        -6
#  DJE        -6
#  BOB       -10
#  WNZ       -16
#  LXR       -18
#  TRN       -40
#  OLB       -42
#  GUM       -48
#
#  [1559 rows x 1 columns],           pax
#  arr_port
#  LHR       869
#  LAX       775
#  LAS       681
#  CDG       610
#  SFO       591
#  DXB       587
#  BKK       560
#  MCO       525
#  JFK       502
#  MUC       477
#  ORD       460
#  MAD       451
#  MIA       445
#  EWR       430
#  IST       423
#  FCO       414
#  AMS       405
#  DEL       400
#  SYD       399
#  LGA       398
#  VIE       384
#  BOM       371
#  ATL       371
#  DFW       369
#  FLL       366
#  CUN       362
#  BCN       350
#  BOS       334
#  FRA       333
#  JED       323
#  ...       ...
#  LFW        -2
#  EUN        -2
#  CAY        -2
#  XNB        -2
#  XOP        -2
#  SHW        -2
#  NKC        -3
#  CJU        -3
#  KZO        -3
#  XJY        -3
#  FOR        -3
#  KKJ        -4
#  AOJ        -4
#  NLK        -4
#  FLA        -4
#  APW        -4
#  SDK        -4
#  OXB        -4
#  UPG        -4
#  ABS        -5
#  MSO        -5
#  LEJ        -5
#  ULN        -6
#  RGI       -10
#  FCA       -11
#  FTE       -12
#  RFP       -14
#  RRG       -22
#  SJO       -33
#  OSD       -38
#
#  [1575 rows x 1 columns],           pax
#  arr_port
#  LHR       872
#  JFK       852
#  LAS       725
#  MCO       683
#  MIA       632
#  BKK       631
#  ORD       614
#  CDG       596
#  SFO       527
#  DXB       518
#  LAX       496
#  IST       457
#  CUN       409
#  MAD       397
#  DFW       388
#  LGA       368
#  BCN       353
#  ORY       350
#  MNL       349
#  MEX       349
#  DEL       344
#  MUC       341
#  EWR       340
#  LIS       332
#  ATL       326
#  HKG       326
#  AMS       320
#  GVA       318
#  BOM       317
#  BOS       309
#  ...       ...
#  EJA        -4
#  SLU        -4
#  KUU        -4
#  RMQ        -4
#  PRI        -4
#  EKO        -4
#  INH        -4
#  LOP        -4
#  SIT        -4
#  XWG        -4
#  PEM        -4
#  DYU        -4
#  PPN        -5
#  ASR        -5
#  WDH        -5
#  NCL        -6
#  ROR        -6
#  HOR        -6
#  QSF        -6
#  LCA        -6
#  LFW        -6
#  OXB        -6
#  JOG        -7
#  DME        -7
#  IXB        -7
#  ZNZ       -10
#  ALC       -13
#  FLW       -19
#  HRK       -19
#  MZV       -35
#
#  [1529 rows x 1 columns],           pax
#  arr_port
#  LAS       786
#  LHR       727
#  LAX       703
#  MCO       670
#  BKK       645
#  SFO       592
#  CDG       589
#  DXB       572
#  LGA       544
#  MIA       526
#  ORD       493
#  JFK       481
#  FCO       461
#  BCN       427
#  DFW       422
#  DEL       417
#  ATL       407
#  HKG       401
#  CUN       384
#  ATH       363
#  DEN       359
#  MAD       352
#  SYD       340
#  BOS       340
#  BOM       333
#  ORY       330
#  SEA       321
#  TXL       315
#  MUC       310
#  IST       307
#  ...       ...
#  SFL        -2
#  GOP        -2
#  MGF        -2
#  ULN        -3
#  RAB        -3
#  CCP        -3
#  IXZ        -3
#  SHW        -3
#  MOZ        -4
#  MVY        -4
#  YXY        -4
#  MIR        -4
#  LAU        -4
#  MPH        -4
#  CSG        -4
#  BPS        -5
#  BOB        -6
#  ERZ        -6
#  LRM        -6
#  LTN        -6
#  ZYL        -7
#  SDJ        -7
#  ITO        -7
#  JRO        -9
#  SXR        -9
#  INN       -10
#  LAP       -12
#  MHH       -12
#  SPN       -13
#  SPC      -108
#
#  [1553 rows x 1 columns],            pax
#  arr_port
#  LHR       1006
#  MCO        861
#  JFK        795
#  LAX        761
#  BKK        747
#  LAS        736
#  SFO        705
#  ORD        686
#  CDG        676
#  DXB        587
#  MIA        585
#  EWR        539
#  DFW        514
#  ATL        498
#  IST        497
#  FCO        479
#  LGA        472
#  CUN        447
#  FLL        435
#  DEN        403
#  HKG        400
#  BOS        387
#  DCA        381
#  PHX        377
#  PEK        375
#  SEA        363
#  BOM        361
#  MAD        356
#  HNL        352
#  MUC        344
#  ...        ...
#  UBP         -2
#  URY         -2
#  XUZ         -2
#  HDS         -2
#  YAY         -2
#  EZS         -2
#  MAO         -3
#  IGU         -3
#  HMB         -3
#  ASU         -3
#  JHB         -3
#  LDH         -4
#  ASR         -4
#  XMB         -4
#  RFP         -4
#  FSC         -5
#  BOB         -5
#  KLU         -6
#  KSN         -6
#  LGK         -6
#  STS         -6
#  BEL         -8
#  PRI         -8
#  RAR         -8
#  MOZ        -14
#  RIX        -21
#  DBV        -30
#  LXR        -30
#  KZN        -45
#  AYQ       -146
#
#  [1506 rows x 1 columns],           pax
#  arr_port
#  LHR       968
#  MCO       870
#  LAS       781
#  MIA       706
#  CDG       700
#  LAX       697
#  CUN       676
#  SFO       616
#  JFK       603
#  BCN       584
#  DXB       560
#  BKK       533
#  ORD       496
#  IST       473
#  DFW       454
#  ATL       406
#  FCO       404
#  MAD       389
#  TXL       374
#  DEN       363
#  PHX       357
#  MNL       354
#  FRA       352
#  SEA       350
#  BOM       344
#  MUC       343
#  JNB       331
#  DEL       330
#  MEL       325
#  DCA       325
#  ...       ...
#  ZLO        -2
#  CRK        -2
#  ZDH        -2
#  BOB        -2
#  BTU        -2
#  KUA        -2
#  CFE        -2
#  TGG        -2
#  ISN        -2
#  LUG        -2
#  JIB        -2
#  TAC        -2
#  LBF        -2
#  KVA        -3
#  AXU        -3
#  MCZ        -3
#  RAB        -4
#  REP        -4
#  VLI        -4
#  LPB        -4
#  PRI        -4
#  CWB        -5
#  FUK        -5
#  ESU        -6
#  NAV        -6
#  XNN        -6
#  SKP        -7
#  VXE        -8
#  FCA       -10
#  KGD       -59
#
#  [1496 rows x 1 columns],            pax
#  arr_port
#  LHR       1024
#  MCO        785
#  LAX        774
#  LAS        739
#  CDG        705
#  JFK        693
#  BKK        648
#  DXB        631
#  SFO        590
#  MIA        586
#  ORD        513
#  MAD        493
#  DFW        491
#  IST        477
#  FCO        464
#  ATL        422
#  BCN        396
#  BOS        390
#  EWR        386
#  PHX        381
#  MNL        379
#  CUN        378
#  ORY        357
#  LGA        354
#  HKG        352
#  TXL        344
#  SYD        342
#  AMS        334
#  BOM        332
#  DEN        332
#  ...        ...
#  STW         -1
#  TMM         -1
#  PTG         -1
#  PUQ         -1
#  KYA         -2
#  DOM         -2
#  HMA         -2
#  FNA         -2
#  MSU         -2
#  KPO         -2
#  TAG         -2
#  UDI         -2
#  RMQ         -2
#  TUG         -2
#  ASM         -2
#  VDM         -2
#  MRA         -2
#  LTN         -2
#  LEI         -2
#  CGD         -3
#  OBO         -6
#  EBL         -7
#  SAH         -9
#  DRW        -10
#  FTE        -12
#  AJR        -12
#  AAL        -19
#  ACE        -42
#  SXF       -112
#  LCA       -116
#
#  [1477 rows x 1 columns],           pax
#  arr_port
#  LHR       952
#  MIA       791
#  LAX       737
#  CDG       714
#  JFK       713
#  MCO       697
#  SFO       636
#  BKK       611
#  LAS       602
#  ORD       546
#  FCO       545
#  DXB       506
#  IST       499
#  ATL       485
#  BCN       475
#  MAD       468
#  DFW       434
#  CUN       431
#  LGA       418
#  BOS       404
#  EWR       400
#  HKG       380
#  FRA       380
#  JED       373
#  SYD       365
#  MNL       355
#  ORY       355
#  FLL       351
#  YYZ       343
#  BOM       331
#  ...       ...
#  FCA        -3
#  SUB        -3
#  SDJ        -4
#  TMS        -4
#  INN        -4
#  RSU        -4
#  IXA        -4
#  JER        -4
#  YFC        -4
#  SPU        -4
#  ZNZ        -4
#  LFW        -5
#  YQL        -5
#  DIE        -5
#  MRA        -5
#  FAE        -6
#  MCZ        -6
#  ASM        -6
#  HAK        -6
#  BTU        -7
#  SID        -7
#  NSN        -7
#  SLU        -8
#  NOS        -8
#  HDN       -10
#  ASR       -10
#  CTS       -10
#  AZS       -11
#  LLA       -11
#  SCQ       -98
#
#  [1534 rows x 1 columns],           pax
#  arr_port
#  LHR       729
#  MCO       686
#  JFK       684
#  LAX       673
#  CDG       637
#  BCN       594
#  LAS       550
#  DXB       549
#  MIA       539
#  SFO       495
#  IST       480
#  BKK       480
#  CUN       479
#  FCO       473
#  MAD       437
#  ORD       425
#  DFW       403
#  ATL       379
#  LGA       374
#  EWR       366
#  DEL       360
#  MNL       347
#  BOS       341
#  BOM       326
#  SIN       324
#  ORY       322
#  YYZ       321
#  SYD       320
#  DEN       313
#  ATH       311
#  ...       ...
#  HDG        -2
#  RCB        -2
#  UIB        -2
#  JPA        -2
#  BTS        -3
#  JRO        -3
#  MWZ        -3
#  IKT        -3
#  ISU        -3
#  ABT        -4
#  SNE        -4
#  UAQ        -4
#  GDZ        -4
#  GAY        -4
#  KKE        -4
#  KWL        -4
#  NDR        -4
#  NVT        -5
#  ALF        -5
#  SMX        -5
#  SLU        -6
#  LUG        -6
#  STM        -6
#  LPB        -6
#  CRK        -7
#  ZCO        -8
#  MYJ        -8
#  RRG       -11
#  URC       -12
#  SPU       -24
#
#  [1543 rows x 1 columns],           pax
#  arr_port
#  LHR       792
#  LAS       711
#  MCO       646
#  JFK       603
#  LAX       602
#  BKK       596
#  SFO       577
#  DXB       570
#  FCO       547
#  CDG       537
#  ORD       514
#  DEL       448
#  LGA       407
#  AMS       404
#  MAD       400
#  IST       395
#  MIA       388
#  EWR       373
#  DFW       363
#  SYD       359
#  BOS       357
#  FRA       335
#  PEK       334
#  MUC       333
#  HKG       324
#  TXL       320
#  CUN       316
#  ATL       315
#  DCA       313
#  IAH       308
#  ...       ...
#  JST        -2
#  ZOS        -2
#  APL        -2
#  OSM        -2
#  SWA        -3
#  BJV        -3
#  RRG        -3
#  KMG        -3
#  POZ        -3
#  ROT        -4
#  LAO        -4
#  KYA        -4
#  KLO        -4
#  VFA        -4
#  HAH        -4
#  JRH        -4
#  ROB        -5
#  MLN        -6
#  HOR        -6
#  GND        -8
#  SEZ        -8
#  USH        -8
#  UPG        -8
#  KVG       -10
#  SPN       -14
#  BKI       -14
#  JOG       -18
#  CXR       -20
#  OPO       -30
#  KRN       -40
#
#  [1559 rows x 1 columns],           pax
#  arr_port
#  LHR       942
#  LAX       835
#  JFK       701
#  CDG       685
#  MCO       670
#  LAS       652
#  MIA       617
#  ORD       573
#  BKK       495
#  DXB       479
#  SFO       471
#  FCO       421
#  SYD       421
#  LGA       419
#  BOS       413
#  TXL       404
#  DFW       404
#  TLV       402
#  MAD       398
#  SEA       378
#  PVG       378
#  IST       377
#  ATL       369
#  FRA       353
#  DEL       349
#  BCN       345
#  BOM       335
#  AMS       330
#  MNL       329
#  CUN       318
#  ...       ...
#  YKM        -2
#  KGF        -2
#  BGM        -2
#  TZX        -2
#  HAH        -2
#  GTR        -2
#  ZYL        -3
#  LSC        -3
#  FLN        -3
#  SHA        -3
#  ASW        -3
#  LYP        -3
#  AGA        -3
#  BBA        -3
#  BPN        -3
#  LLW        -3
#  REP        -4
#  XWG        -4
#  GWT        -4
#  PRI        -4
#  ROB        -5
#  MUA        -6
#  CSX        -6
#  DJE        -6
#  BOB       -10
#  WNZ       -16
#  LXR       -18
#  TRN       -40
#  OLB       -42
#  GUM       -48
#
#  [1559 rows x 1 columns],           pax
#  arr_port
#  LHR       869
#  LAX       775
#  LAS       681
#  CDG       610
#  SFO       591
#  DXB       587
#  BKK       560
#  MCO       525
#  JFK       502
#  MUC       477
#  ORD       460
#  MAD       451
#  MIA       445
#  EWR       430
#  IST       423
#  FCO       414
#  AMS       405
#  DEL       400
#  SYD       399
#  LGA       398
#  VIE       384
#  BOM       371
#  ATL       371
#  DFW       369
#  FLL       366
#  CUN       362
#  BCN       350
#  BOS       334
#  FRA       333
#  JED       323
#  ...       ...
#  LFW        -2
#  EUN        -2
#  CAY        -2
#  XNB        -2
#  XOP        -2
#  SHW        -2
#  NKC        -3
#  CJU        -3
#  KZO        -3
#  XJY        -3
#  FOR        -3
#  KKJ        -4
#  AOJ        -4
#  NLK        -4
#  FLA        -4
#  APW        -4
#  SDK        -4
#  OXB        -4
#  UPG        -4
#  ABS        -5
#  MSO        -5
#  LEJ        -5
#  ULN        -6
#  RGI       -10
#  FCA       -11
#  FTE       -12
#  RFP       -14
#  RRG       -22
#  SJO       -33
#  OSD       -38
#
#  [1575 rows x 1 columns],           pax
#  arr_port
#  LHR       872
#  JFK       852
#  LAS       725
#  MCO       683
#  MIA       632
#  BKK       631
#  ORD       614
#  CDG       596
#  SFO       527
#  DXB       518
#  LAX       496
#  IST       457
#  CUN       409
#  MAD       397
#  DFW       388
#  LGA       368
#  BCN       353
#  ORY       350
#  MNL       349
#  MEX       349
#  DEL       344
#  MUC       341
#  EWR       340
#  LIS       332
#  ATL       326
#  HKG       326
#  AMS       320
#  GVA       318
#  BOM       317
#  BOS       309
#  ...       ...
#  EJA        -4
#  SLU        -4
#  KUU        -4
#  RMQ        -4
#  PRI        -4
#  EKO        -4
#  INH        -4
#  LOP        -4
#  SIT        -4
#  XWG        -4
#  PEM        -4
#  DYU        -4
#  PPN        -5
#  ASR        -5
#  WDH        -5
#  NCL        -6
#  ROR        -6
#  HOR        -6
#  QSF        -6
#  LCA        -6
#  LFW        -6
#  OXB        -6
#  JOG        -7
#  DME        -7
#  IXB        -7
#  ZNZ       -10
#  ALC       -13
#  FLW       -19
#  HRK       -19
#  MZV       -35
#
#  [1529 rows x 1 columns],           pax
#  arr_port
#  LAS       786
#  LHR       727
#  LAX       703
#  MCO       670
#  BKK       645
#  SFO       592
#  CDG       589
#  DXB       572
#  LGA       544
#  MIA       526
#  ORD       493
#  JFK       481
#  FCO       461
#  BCN       427
#  DFW       422
#  DEL       417
#  ATL       407
#  HKG       401
#  CUN       384
#  ATH       363
#  DEN       359
#  MAD       352
#  SYD       340
#  BOS       340
#  BOM       333
#  ORY       330
#  SEA       321
#  TXL       315
#  MUC       310
#  IST       307
#  ...       ...
#  SFL        -2
#  GOP        -2
#  MGF        -2
#  ULN        -3
#  RAB        -3
#  CCP        -3
#  IXZ        -3
#  SHW        -3
#  MOZ        -4
#  MVY        -4
#  YXY        -4
#  MIR        -4
#  LAU        -4
#  MPH        -4
#  CSG        -4
#  BPS        -5
#  BOB        -6
#  ERZ        -6
#  LRM        -6
#  LTN        -6
#  ZYL        -7
#  SDJ        -7
#  ITO        -7
#  JRO        -9
#  SXR        -9
#  INN       -10
#  LAP       -12
#  MHH       -12
#  SPN       -13
#  SPC      -108
#
#  [1553 rows x 1 columns],           pax
#  arr_port
#  LAS         4
#  MAA         2
#  MEL         2
#  ORY         2
#  RDU         1]

# %%
c = pd.DataFrame([])
hePasadoYaporChunk1 = False

for chunk in b:
    print('Procesando chunk')
    s = chunk.groupby("arr_port").pax.sum().reset_index()
    if hePasadoYaPorChunk1:
        c = pd.concat([s,todosLosDf])
    else:
        c = s
        hePasadoYaPorChunk1 = True
    todosLosDf = c.groupby ('arr_port').pax.sum().reset_index()     

# error podemos ignorar aeropuertos no en cada top 10

todosLosDf.sort('pax', ascending=False).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-975cb8dab7d8> in <module>()
#      14 # error podemos ignorar aeropuertos no en cada top 10
#      15
# ---> 16 todosLosDf.sort('pax', ascending=False).head()
#
# NameError: name 'todosLosDf' is not defined

# %%
top = d.sort('pax', ascending=False).head(5)

# %%
from GeoBases import GeoBase

# %%
g = GeoBase(data='ori_por', verbose=False)

# %%
g.get('MUC')['name']
# Out:
# 'Munich International Airport'

# %%
names = []
for x in top.arr_port:
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-72e763e9e2fb> in <module>()
# ----> 1 top.arr_port
#
# NameError: name 'top' is not defined
